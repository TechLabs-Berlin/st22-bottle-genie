# %%
import pandas as pd

# %%
df = pd.read_csv('Database.csv')

# %%
df
# Out:
#      Unnamed: 0 Unnamed: 1                      Unnamed: 2 Unnamed: 3  \
# 0           NaN      Store                           Brand   Material
# 1           NaN      Penny       Lichtenauer Fresh n Fruit    Plastic
# 2           NaN      Penny    Bullit Energy Drink Original    Plastic
# 3           NaN      Penny    Bullit Energy Drink Original    Plastic
# 4           NaN      Penny  Bullit Energy Drink GrapeFruit    Plastic
# ..          ...        ...                             ...        ...
# 479         NaN       Aldi         Rio D Oro Smoothie Plus    Plastic
# 480         NaN       Aldi                  Paulaner Spezi  Aluminium
# 481         NaN       Aldi                  Coca Cola Zero  Aluminium
# 482         NaN       Aldi                       Coca Cola  Aluminium
# 483         NaN       Aldi        Ileburger Brause Himbeer    Plastic
#
#      Unnamed: 4     Unnamed: 5
# 0    Volume (L)  Value (Euros)
# 1           1,5           0,25
# ...

# %%
import numpy as np

# %%
df.drop(columns='Unnamed: 0', inplace=True)

# %%
df
# Out:
#     Unnamed: 1                      Unnamed: 2 Unnamed: 3  Unnamed: 4  \
# 0        Store                           Brand   Material  Volume (L)
# 1        Penny       Lichtenauer Fresh n Fruit    Plastic         1,5
# 2        Penny    Bullit Energy Drink Original    Plastic         0,5
# 3        Penny    Bullit Energy Drink Original    Plastic         1,5
# 4        Penny  Bullit Energy Drink GrapeFruit    Plastic           1
# ..         ...                             ...        ...         ...
# 479       Aldi         Rio D Oro Smoothie Plus    Plastic        0,25
# 480       Aldi                  Paulaner Spezi  Aluminium        0,33
# 481       Aldi                  Coca Cola Zero  Aluminium        0,33
# 482       Aldi                       Coca Cola  Aluminium        0,33
# 483       Aldi        Ileburger Brause Himbeer    Plastic         1,5
#
#         Unnamed: 5
# 0    Value (Euros)
# 1             0,25
# 2             0,25
# 3             0,25
# 4             0,25
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5'], dtype='object')

# %%
df.columns = [ 'Store', 'Brand', 'Material', 'Volume', 'Value']

# %%
df
# Out:
#      Store                           Brand   Material      Volume  \
# 0    Store                           Brand   Material  Volume (L)
# 1    Penny       Lichtenauer Fresh n Fruit    Plastic         1,5
# 2    Penny    Bullit Energy Drink Original    Plastic         0,5
# 3    Penny    Bullit Energy Drink Original    Plastic         1,5
# 4    Penny  Bullit Energy Drink GrapeFruit    Plastic           1
# ..     ...                             ...        ...         ...
# 479   Aldi         Rio D Oro Smoothie Plus    Plastic        0,25
# 480   Aldi                  Paulaner Spezi  Aluminium        0,33
# 481   Aldi                  Coca Cola Zero  Aluminium        0,33
# 482   Aldi                       Coca Cola  Aluminium        0,33
# 483   Aldi        Ileburger Brause Himbeer    Plastic         1,5
#
#              Value
# 0    Value (Euros)
# 1             0,25
# 2             0,25
# 3             0,25
# 4             0,25
# ..             ...
# 479           0,25
# ...

# %%
df.drop(index=0)
# Out:
#      Store                           Brand   Material Volume Value
# 1    Penny       Lichtenauer Fresh n Fruit    Plastic    1,5  0,25
# 2    Penny    Bullit Energy Drink Original    Plastic    0,5  0,25
# 3    Penny    Bullit Energy Drink Original    Plastic    1,5  0,25
# 4    Penny  Bullit Energy Drink GrapeFruit    Plastic      1  0,25
# 5    Penny                  Monster Energy  Aluminium    0,5  0,25
# ..     ...                             ...        ...    ...   ...
# 479   Aldi         Rio D Oro Smoothie Plus    Plastic   0,25  0,25
# 480   Aldi                  Paulaner Spezi  Aluminium   0,33  0,25
# 481   Aldi                  Coca Cola Zero  Aluminium   0,33  0,25
# 482   Aldi                       Coca Cola  Aluminium   0,33  0,25
# 483   Aldi        Ileburger Brause Himbeer    Plastic    1,5  0,25
#
# [483 rows x 5 columns]

# %%
result1 = df.loc[df.Brand.isin(["Fanta"])&df.Material.isin(["Plastic"])&df.Volume.isin(["0,5"]), ["Store"]]
print(result1.to_string (index = False))
# Out:
#  Store
#  Edeka

# %%
result2 = df.loc[df.Brand.isin(["Red Bull Energy Drink"])&df.Material.isin(["Aluminium"])&df.Volume.isin(["0,25"]), ["Store"]]
print(result2.to_string (index = False))
# Out:
#  Store
#   Rewe
#  Edeka

# %%
result3= df.loc[df.Brand.isin(["Coca Cola"])&df.Material.isin(["Aluminium"])&df.Volume.isin(["0,"]), ["Store"]]
print(result2.to_string (index = False))
# Out:
#  Store
#   Rewe
#  Edeka

# %%
final = result1.merge(result2, how='left').merge(result3, how='left')
print(final.to_string (index = False))
# Out:
#  Store
#  Edeka

# %%
teste = df.loc[df.Brand.isin([input("Brand: ")])&df.Material.isin([input("Material: ")])&df.Volume.isin([input("Volume: ")]), ["Store"]]
# Out:
# Brand: Coca Cola
# Material: Plastic
# Volume: 1

# %%
print(teste)
# Out:
#     Store
# 133  Rewe
